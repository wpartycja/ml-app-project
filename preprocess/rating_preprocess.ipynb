# %%
import pandas as pd

# %%
movies_df = pd.read_csv('./preprocessed_data/movies_preprocessed.csv')
movies_df.head()
# Out:
#    Unnamed: 0  adult                              belongs_to_collection  \
# 0           0  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1           1  False                                                NaN
# 2           2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3           3  False                                                NaN
# 4           4  False  {'id': 96871, 'name': 'Father of the Bride Col...
#
#      budget                                             genres  \
# 0  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45296 entries, 0 to 45295
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             45296 non-null  int64
#  1   adult                  45296 non-null  bool
#  2   belongs_to_collection  4477 non-null   object
#  3   budget                 45296 non-null  int64
#  4   genres                 45296 non-null  object
#  5   homepage               7959 non-null   object
#  6   id                     45296 non-null  int64
#  7   imdb_id                45281 non-null  object
#  8   original_language      45286 non-null  object
#  9   original_title         45296 non-null  object
#  10  overview               45296 non-null  object
#  11  popularity             45292 non-null  float64
#  12  poster_path            44951 non-null  object
#  13  production_companies   45292 non-null  object
# ...

# %%
movies_ids = movies_df['id']
movies_ids
# Out:
# 0           862
# 1          8844
# 2         15602
# 3         31357
# 4         11862
#           ...
# 45291    439050
# 45292    111109
# 45293     67758
# 45294    227506
# 45295    461257
# Name: id, Length: 45296, dtype: int64

# %%
ratings_df = pd.read_csv('./data/ratings_small.csv')

# %%
ratings_df.drop(columns=['timestamp'], inplace=True)

# %%
ratings_df[ratings_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating]
# Index: []

# %%
ratings_df.dropna(inplace=True)

# %%
ratings_df = ratings_df.loc[ratings_df['movieId'].isin(movies_ids)]

# %%
def change_rating_scale(rating):
    return rating * 2

ratings_df['rating'] = ratings_df['rating'].apply(lambda x: change_rating_scale(x))
ratings_df['rating'].value_counts()
# Out:
# 8.0     13087
# 6.0      9840
# 10.0     7273
# 7.0      4009
# 4.0      3215
# 9.0      2994
# 5.0      1712
# 2.0      1510
# 3.0       646
# 1.0       406
# Name: rating, dtype: int64

# %%
ratings_df.head()
# Out:
#     userId  movieId  rating
# 10       1     1371     5.0
# 11       1     1405     2.0
# 13       1     2105     8.0
# 15       1     2193     4.0
# 16       1     2294     4.0

# %%
ratings_df.to_csv('./preprocessed_data/ratings_small_preprocessed.csv')
